# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
dframe = pd.read_csv('2018_Building_Energy_Benchmarking.csv')

# %%
dframe
# Out:
#       OSEBuildingID  DataYear                            BuildingName  \
# 0                 1      2018                    MAYFLOWER PARK HOTEL
# 1                 2      2018                         PARAMOUNT HOTEL
# 2                 3      2018          WESTIN HOTEL (Parent Building)
# 3                 5      2018                               HOTEL MAX
# 4                 8      2018                   WARWICK SEATTLE HOTEL
# ...             ...       ...                                     ...
# 3532          50414      2018                           OTHELLO NORTH
# 3533          50415      2018  PORT OF SEATTLE- TERMINAL 115 (CAMPUS)
# 3534          50416      2018   PORT OF SEATTLE- TERMINAL 91 (CAMPUS)
# 3535          50452      2018     PORT OF SEATTLE - TERMINAL 5 CAMPUS
# 3536          50453      2018           PORT OF SEATTLE - TERMINAL 86
#
#               BuildingType TaxParcelIdentificationNumber  \
# 0           NonResidential                    0659000030
# ...

# %%
dframe = pd.read_csv('2018_Building_Energy_Benchmarking.csv', header = None)

# %%
dframe
# Out:
#                  0         1                                       2   \
# 0     OSEBuildingID  DataYear                            BuildingName
# 1                 1      2018                    MAYFLOWER PARK HOTEL
# 2                 2      2018                         PARAMOUNT HOTEL
# 3                 3      2018          WESTIN HOTEL (Parent Building)
# 4                 5      2018                               HOTEL MAX
# ...             ...       ...                                     ...
# 3533          50414      2018                           OTHELLO NORTH
# 3534          50415      2018  PORT OF SEATTLE- TERMINAL 115 (CAMPUS)
# 3535          50416      2018   PORT OF SEATTLE- TERMINAL 91 (CAMPUS)
# 3536          50452      2018     PORT OF SEATTLE - TERMINAL 5 CAMPUS
# 3537          50453      2018           PORT OF SEATTLE - TERMINAL 86
#
#                         3                              4   \
# 0             BuildingType  TaxParcelIdentificationNumber
# ...

# %%
dframe.fillna('NaN', inplace=True)

# %%
dframe
# Out:
#                  0         1                                       2   \
# 0     OSEBuildingID  DataYear                            BuildingName
# 1                 1      2018                    MAYFLOWER PARK HOTEL
# 2                 2      2018                         PARAMOUNT HOTEL
# 3                 3      2018          WESTIN HOTEL (Parent Building)
# 4                 5      2018                               HOTEL MAX
# ...             ...       ...                                     ...
# 3533          50414      2018                           OTHELLO NORTH
# 3534          50415      2018  PORT OF SEATTLE- TERMINAL 115 (CAMPUS)
# 3535          50416      2018   PORT OF SEATTLE- TERMINAL 91 (CAMPUS)
# 3536          50452      2018     PORT OF SEATTLE - TERMINAL 5 CAMPUS
# 3537          50453      2018           PORT OF SEATTLE - TERMINAL 86
#
#                         3                              4   \
# 0             BuildingType  TaxParcelIdentificationNumber
# ...

# %%
ENERGYSTARSCore_index = dframe[dframe[22] == 'NaN']

# %%
ENERGYSTARSCore_index
# Out:
#          0     1                                                  2   \
# 89      135  2018                              CERTAINTEED WAREHOUSE
# 95      141  2018  HUGHES ELEMENTARY SCHOOL - Under Construction ...
# 130     215  2018                             RAINIER BOTTLING PLANT
# 146     237  2018                 WHITTIER ELEMENTARY (SPS-DISTRICT)
# 150     242  2018                        OLYMPIC VIEW (SPS-DISTRICT)
# ...     ...   ...                                                ...
# 3511  50336  2018                           TWENTY 20 MAD APARTMENTS
# 3513  50338  2018                                     HARLOW HEIGHTS
# 3515  50341  2018                                    VEGA APARTMENTS
# 3518  50344  2018                                     ORI APARTMENTS
# 3524  50351  2018                                         STREAM 403
#
#                         3           4                       5        6   7   \
# ...

# %%
dframe.drop(ENERGYSTARSCore_index, inplace= True)

# %%
dframe
# Out:
#          0     1                                       2   \
# 42       56  2018                          HILTON SEATTLE
# 43       57  2018                              5TH & PINE
# 44       58  2018                   CENTURY SQUARE RETAIL
# 45       59  2018                         GIBRALTAR TOWER
# 46       60  2018   MANN BUILDING/WILD GINGER/TRIPLE DOOR
# ...     ...   ...                                     ...
# 3533  50414  2018                           OTHELLO NORTH
# 3534  50415  2018  PORT OF SEATTLE- TERMINAL 115 (CAMPUS)
# 3535  50416  2018   PORT OF SEATTLE- TERMINAL 91 (CAMPUS)
# 3536  50452  2018     PORT OF SEATTLE - TERMINAL 5 CAMPUS
# 3537  50453  2018           PORT OF SEATTLE - TERMINAL 86
#
#                         3           4                          5        6   \
# 42          NonResidential  7802920020               1301 6TH AVE  SEATTLE
# 43          NonResidential  1975700200               1513 5TH AVE  SEATTLE
# ...

# %%
dframe
# Out:
#          0     1                                       2   \
# 42       56  2018                          HILTON SEATTLE
# 43       57  2018                              5TH & PINE
# 44       58  2018                   CENTURY SQUARE RETAIL
# 45       59  2018                         GIBRALTAR TOWER
# 46       60  2018   MANN BUILDING/WILD GINGER/TRIPLE DOOR
# ...     ...   ...                                     ...
# 3533  50414  2018                           OTHELLO NORTH
# 3534  50415  2018  PORT OF SEATTLE- TERMINAL 115 (CAMPUS)
# 3535  50416  2018   PORT OF SEATTLE- TERMINAL 91 (CAMPUS)
# 3536  50452  2018     PORT OF SEATTLE - TERMINAL 5 CAMPUS
# 3537  50453  2018           PORT OF SEATTLE - TERMINAL 86
#
#                         3           4                          5        6   \
# 42          NonResidential  7802920020               1301 6TH AVE  SEATTLE
# 43          NonResidential  1975700200               1513 5TH AVE  SEATTLE
# ...

# %%
type(dframe)
# Out:
# pandas.core.frame.DataFrame

# %%
dframe = dframe.loc[~dframe[2].str.contains('CENTER'), :]

# %%
dframe
# Out:
#          0     1                                       2   \
# 42       56  2018                          HILTON SEATTLE
# 43       57  2018                              5TH & PINE
# 44       58  2018                   CENTURY SQUARE RETAIL
# 45       59  2018                         GIBRALTAR TOWER
# 46       60  2018   MANN BUILDING/WILD GINGER/TRIPLE DOOR
# ...     ...   ...                                     ...
# 3533  50414  2018                           OTHELLO NORTH
# 3534  50415  2018  PORT OF SEATTLE- TERMINAL 115 (CAMPUS)
# 3535  50416  2018   PORT OF SEATTLE- TERMINAL 91 (CAMPUS)
# 3536  50452  2018     PORT OF SEATTLE - TERMINAL 5 CAMPUS
# 3537  50453  2018           PORT OF SEATTLE - TERMINAL 86
#
#                         3           4                          5        6   \
# 42          NonResidential  7802920020               1301 6TH AVE  SEATTLE
# 43          NonResidential  1975700200               1513 5TH AVE  SEATTLE
# ...

# %%
# BuildingNameContains_center = dframe[dframe[2].str.contains('CENTER')]

# %%
# BuildingNameContains_center

# %%
# YearBuilt_convert_to_integer = dframe[13].astype(int)

# %%
# YearBuilt_less_than_1920 = YearBuilt_convert_to_integer < 1920

# %%
# YearBuilt_less_than_1920

# %%
# dframe.drop(YearBuilt_less_than_1920, inplace=True)
# dframe = dframe.loc[~dframe[13].astype(int)<1920, :]
dframe=dframe[np.invert(dframe.loc[:,13].astype(int)<1920)]

# %%
dframe
# Out:
#          0     1                                       2   \
# 42       56  2018                          HILTON SEATTLE
# 43       57  2018                              5TH & PINE
# 44       58  2018                   CENTURY SQUARE RETAIL
# 46       60  2018   MANN BUILDING/WILD GINGER/TRIPLE DOOR
# 47       62  2018        ROOSEVELT HOTEL (HOTEL THEODORE)
# ...     ...   ...                                     ...
# 3533  50414  2018                           OTHELLO NORTH
# 3534  50415  2018  PORT OF SEATTLE- TERMINAL 115 (CAMPUS)
# 3535  50416  2018   PORT OF SEATTLE- TERMINAL 91 (CAMPUS)
# 3536  50452  2018     PORT OF SEATTLE - TERMINAL 5 CAMPUS
# 3537  50453  2018           PORT OF SEATTLE - TERMINAL 86
#
#                         3           4                          5        6   \
# 42          NonResidential  7802920020               1301 6TH AVE  SEATTLE
# 43          NonResidential  1975700200               1513 5TH AVE  SEATTLE
# ...

# %%
dframe.loc[dframe[15].idxmax()]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-831d35cd3a93> in <module>
# ----> 1 dframe.loc[dframe[15].idxmax()]
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in idxmax(self, axis, skipna, *args, **kwargs)
#    2275         """
#    2276         skipna = nv.validate_argmax_with_skipna(skipna, args, kwargs)
# -> 2277         i = nanops.nanargmax(com.values_from_object(self), skipna=skipna)
#    2278         if i == -1:
#    2279             return np.nan
#
# ~\Anaconda3\lib\site-packages\pandas\core\nanops.py in _f(*args, **kwargs)
#      65             if any(self.check(obj) for obj in obj_iter):
#      66                 msg = "reduction operation {name!r} not allowed for this dtype"
# ---> 67                 raise TypeError(msg.format(name=f.__name__.replace("nan", "")))
#      68             try:
# ...

# %%
ENERGYSTARScore_over_97 = dframe[dframe[20] >=97]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-8644e25c622a> in <module>
# ----> 1 ENERGYSTARScore_over_97 = dframe[dframe[20] >=97]
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other, axis)
#    1227
#    1228             with np.errstate(all="ignore"):
# -> 1229                 res = na_op(values, other)
#    1230             if is_scalar(res):
#    1231                 raise TypeError(
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in na_op(x, y)
#    1089
#    1090         if is_object_dtype(x.dtype):
# -> 1091             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1092
#    1093         elif is_datetimelike_v_numeric(x, y):
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops\__init__.py in _comp_method_OBJECT_ARRAY(op, x, y)
#    1067         result = libops.vec_compare(x, y, op)
#    1068     else:
# ...
